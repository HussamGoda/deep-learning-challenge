# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import permutation_importance
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df=application_df.drop(columns=["EIN", "NAME"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   APPLICATION_TYPE        34299 non-null  object
#  1   AFFILIATION             34299 non-null  object
#  2   CLASSIFICATION          34299 non-null  object
#  3   USE_CASE                34299 non-null  object
#  4   ORGANIZATION            34299 non-null  object
#  5   STATUS                  34299 non-null  int64
#  6   INCOME_AMT              34299 non-null  object
#  7   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  8   ASK_AMT                 34299 non-null  int64
#  9   IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 2.6+ MB

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE

attrition_cat = application_df.columns.tolist()
application_df[attrition_cat].nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
value_count_for_each_unique_AppType = application_df['APPLICATION_TYPE'].value_counts()
print(value_count_for_each_unique_AppType)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE

cutoff_value = 527
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
value_count_for_each_unique_classification = application_df['CLASSIFICATION'].value_counts()
print(value_count_for_each_unique_classification)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
values_unique_classification_greater_than_1 = value_count_for_each_unique_classification[value_count_for_each_unique_classification > 1]
print(values_unique_classification_greater_than_1)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
cutoff_value_1 = 1882
classifications_to_replace = application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() < cutoff_value_1].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
columns_to_convert = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']
application_df = pd.get_dummies(application_df, columns=columns_to_convert)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STATUS                        34299 non-null  int64
#  1   ASK_AMT                       34299 non-null  int64
#  2   IS_SUCCESSFUL                 34299 non-null  int64
#  3   APPLICATION_TYPE_Other        34299 non-null  uint8
#  4   APPLICATION_TYPE_T10          34299 non-null  uint8
#  5   APPLICATION_TYPE_T19          34299 non-null  uint8
#  6   APPLICATION_TYPE_T3           34299 non-null  uint8
#  7   APPLICATION_TYPE_T4           34299 non-null  uint8
#  8   APPLICATION_TYPE_T5           34299 non-null  uint8
#  9   APPLICATION_TYPE_T6           34299 non-null  uint8
#  10  APPLICATION_TYPE_T7           34299 non-null  uint8
#  11  APPLICATION_TYPE_T8           34299 non-null  uint8
#  12  AFFILIATION_CompanySponsored  34299 non-null  uint8
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = application_df.IS_SUCCESSFUL.values
X = application_df.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# ## Attempt 1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=70, activation="selu", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=50, activation="selu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 70)                3080
#
#  dense_1 (Dense)             (None, 50)                3550
#
#  dense_2 (Dense)             (None, 1)                 51
#
# ...
# Total params: 6681 (26.10 KB)
# Trainable params: 6681 (26.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5797 - accuracy: 0.7225
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5643 - accuracy: 0.7274
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5593 - accuracy: 0.7301
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5566 - accuracy: 0.7309
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5545 - accuracy: 0.7301
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5545 - accuracy: 0.7281
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5524 - accuracy: 0.7315
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5527 - accuracy: 0.7315
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5507 - accuracy: 0.7324
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5554 - accuracy: 0.7238 - 322ms/epoch - 1ms/step
# Loss: 0.5553554892539978, Accuracy: 0.7238484025001526

# %%
import numpy as np

first_layer_weights = nn.layers[0].get_weights()[0]

# Calculate the absolute sum of weights for each feature
feature_importance = np.abs(first_layer_weights).sum(axis=0)

# Print the feature importance
print("Feature Importance:", feature_importance)
# Out:
# Feature Importance: [ 8.588009   7.882796  11.650814   8.62295    7.8063097  9.564207
#  10.518559   9.162093   6.2612953  5.0624895  7.6041493 10.663862
#  10.718828  10.525672   9.098915  10.526445  11.814692   7.9257727
#   7.0459375  9.927848   9.583272   9.45322    8.83218   14.24625
#   7.361804   6.4692245 11.146006   9.175509  11.52283    8.823426
#  11.633549   8.486638   7.529423  12.091159  11.009068  12.057643
#  10.403478   9.350094   6.1035004 10.700274   8.279676   7.252616
#  12.748878  10.000792  12.185455   9.338516   7.1960163  8.490298
#  10.205889   6.026265  10.869047   5.0714116  7.766021   6.361436
#   3.6428735  9.124666   9.808877  11.178174   6.7116017  7.5363507
#  11.010908   9.838431  11.566252  10.813621  10.157157   8.990688
#  12.679687   8.430364  10.686802   9.5417   ]

# %%
from sklearn.inspection import permutation_importance
from sklearn.ensemble import RandomForestClassifier

# Create a RandomForestClassifier (or any other compatible scikit-learn classifier)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)

# Calculate permutation importance
perm_importance = permutation_importance(rf_model, X_test_scaled, y_test, n_repeats=30, random_state=42)

# Print the permutation importance scores
print("Permutation Importance:", perm_importance.importances_mean)
# Out:
# Permutation Importance: [ 3.88726919e-06  1.10009718e-02 -1.55490768e-04  1.04217687e-02
#   2.21574344e-04  1.04956268e-02  1.64742468e-02  6.09135083e-03
#   2.47619048e-03  9.29057337e-04 -5.79203110e-04  8.46958212e-02
#   3.88726919e-05  2.11000972e-02  2.72108844e-05  0.00000000e+00
#   0.00000000e+00 -3.79786200e-03 -6.60835763e-04 -1.30223518e-03
#  -6.41399417e-04  1.68318756e-03  4.58309038e-03 -5.83090379e-05
#  -2.72108844e-05  0.00000000e+00 -1.47327502e-03  7.89504373e-03
#   3.02818270e-03 -1.08843537e-04  1.20505345e-04  5.05344995e-05
#  -6.16132167e-03  1.07677357e-03 -4.50923226e-04 -3.41302235e-03
#   4.27599611e-05 -8.55199223e-05 -5.40330418e-03  3.57628766e-04
#  -5.44217687e-05 -2.17687075e-04 -2.25461613e-04]

# %% [markdown]
# ## Attempt 2 - Increasing number of hidden neurons

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_2 = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn_2.add(tf.keras.layers.Dense(units=90, activation="selu", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn_2.add(tf.keras.layers.Dense(units=70, activation="selu"))

# Output layer
#  YOUR CODE GOES HERE
nn_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 90)                3960
#
#  dense_13 (Dense)            (None, 70)                6370
#
#  dense_14 (Dense)            (None, 1)                 71
#
# ...
# Total params: 10401 (40.63 KB)
# Trainable params: 10401 (40.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5812 - accuracy: 0.7199
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5655 - accuracy: 0.7281
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5609 - accuracy: 0.7285
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5566 - accuracy: 0.7308
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5559 - accuracy: 0.7315
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5538 - accuracy: 0.7318
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5540 - accuracy: 0.7308
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5529 - accuracy: 0.7308
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.7318
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5559 - accuracy: 0.7216 - 291ms/epoch - 1ms/step
# Loss: 0.5559483766555786, Accuracy: 0.7216326594352722

# %% [markdown]
# ## Attempt 3 - Increasing number of hidden layers - based on nn-2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_3 = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn_3.add(tf.keras.layers.Dense(units=90, activation="selu", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn_3.add(tf.keras.layers.Dense(units=70, activation="selu"))
nn_3.add(tf.keras.layers.Dense(units=50, activation="selu"))
# Output layer
#  YOUR CODE GOES HERE
nn_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn_3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 90)                3960
#
#  dense_16 (Dense)            (None, 70)                6370
#
#  dense_17 (Dense)            (None, 50)                3550
#
#  dense_18 (Dense)            (None, 1)                 51
#
# ...
# Total params: 13931 (54.42 KB)
# Trainable params: 13931 (54.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn_3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn_3.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5768 - accuracy: 0.7196
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5631 - accuracy: 0.7279
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5583 - accuracy: 0.7285
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5563 - accuracy: 0.7295
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5548 - accuracy: 0.7307
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5539 - accuracy: 0.7310
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5531 - accuracy: 0.7312
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5531 - accuracy: 0.7303
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5514 - accuracy: 0.7317
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5556 - accuracy: 0.7245 - 302ms/epoch - 1ms/step
# Loss: 0.5555731058120728, Accuracy: 0.7245481014251709

# %% [markdown]
# ## Attempt 4 - Increasing number of epochs based on nn-3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_4 = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn_4.add(tf.keras.layers.Dense(units=90, activation="selu", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn_4.add(tf.keras.layers.Dense(units=70, activation="selu"))
nn_4.add(tf.keras.layers.Dense(units=50, activation="selu"))

# Output layer
#  YOUR CODE GOES HERE
nn_4.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn_4.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_19 (Dense)            (None, 90)                3960
#
#  dense_20 (Dense)            (None, 70)                6370
#
#  dense_21 (Dense)            (None, 50)                3550
#
#  dense_22 (Dense)            (None, 1)                 51
#
# ...
# Total params: 13931 (54.42 KB)
# Trainable params: 13931 (54.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn_4.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn_4.fit(X_train_scaled, y_train, epochs=300)
# Out:
# Epoch 1/300
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5782 - accuracy: 0.7181
# Epoch 2/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5647 - accuracy: 0.7240
# Epoch 3/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5601 - accuracy: 0.7269
# Epoch 4/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5581 - accuracy: 0.7278
# Epoch 5/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5561 - accuracy: 0.7309
# Epoch 6/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5542 - accuracy: 0.7289
# Epoch 7/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5544 - accuracy: 0.7299
# Epoch 8/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5537 - accuracy: 0.7291
# Epoch 9/300
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5524 - accuracy: 0.7311
# Epoch 10/300
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_4.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5808 - accuracy: 0.7258 - 304ms/epoch - 1ms/step
# Loss: 0.5808266401290894, Accuracy: 0.7258309125900269

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
